# %%
import tensorflow as tf
import numpy as np
# Bir hücrede değişken tanımla
mesaj = "Jupyter sistemimiz hazır!"
print(mesaj)
# Out:
# Jupyter sistemimiz hazır!

# %%
import matplotlib.pyplot as plt

# Rastgele bir AI verisi oluşturalım
data = np.random.rand(10, 10)

# Bunu bir ısı haritası olarak görselleştirelim
plt.imshow(data, cmap='viridis')
plt.colorbar()
plt.title("İlk Jupyter Görselleştirmem!")
plt.show()

# %%
import tensorflow as tf
from osgeo import gdal
import cv2
import numpy as np

print("TensorFlow:", tf.__version__)
print("GDAL:", gdal.__version__)
print("OpenCV:", cv2.__version__)
print("NumPy:", np.__version__)
# Out:
# TensorFlow: 2.10.0
# GDAL: 3.11.4
# OpenCV: 4.9.0
# NumPy: 1.26.4

# %%
print("TensorFlow:", tf.__version__)
print("GDAL:", gdal.__version__)
# Out:
# TensorFlow: 2.10.0
# GDAL: 3.11.4

# %%
import tensorflow as tf
gpu_is_ready = tf.config.list_physical_devices('GPU')

print("="*30)
if gpu_is_ready:
    print(f"✅ EKRAN KARTI HAZIR: {gpu_is_ready[0].name}")
    print("🚀 Artık saatler sürecek eğitimler dakikalar içinde bitecek!")
else:
    print("❌ GPU hala görünmüyor, ama CPU ile de devam edebiliriz.")
print("="*30)
# Out:
# ...
# ✅ EKRAN KARTI HAZIR: /physical_device:GPU:0
# 🚀 Artık saatler sürecek eğitimler dakikalar içinde bitecek!
# ...
